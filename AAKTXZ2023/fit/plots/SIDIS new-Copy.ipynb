# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import least_squares
from matplotlib.backends.backend_pdf import PdfPages
from PIL import Image
import os
import pandas as pd
import numpy as np
import pylab as py
import warnings
import matplotlib.pyplot as plt
from  matplotlib import rc
from matplotlib.colors import LogNorm
from matplotlib import font_manager
import matplotlib
rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
rc('text',usetex=True)
from scipy.interpolate import interp1d
from scipy.interpolate import make_interp_spline as spline
matplotlib.rcParams['text.latex.preamble']=r"\usepackage{amsmath}"
from matplotlib.ticker import ScalarFormatter,MaxNLocator,LogLocator,NullFormatter,FuncFormatter
warnings.filterwarnings('ignore')
import matplotlib.font_manager
from matplotlib.ticker import MultipleLocator, FormatStrFormatter,AutoMinorLocator
from matplotlib.pyplot import gca

# %%
pip_ne_Q2 = np.loadtxt('../plot_data/HERMES/pip_ne_pt2.dat',skiprows=1)[:, 2]
pip_kr_Q2 = np.loadtxt('../plot_data/HERMES/pip_kr_pt2.dat',skiprows=1)[:, 2]
pip_xe_Q2 = np.loadtxt('../plot_data/HERMES/pip_xe_pt2.dat',skiprows=1)[:, 2]

pim_ne_Q2 = np.loadtxt('../plot_data/HERMES/pim_ne_pt2.dat',skiprows=1)[:, 2]
pim_kr_Q2 = np.loadtxt('../plot_data/HERMES/pim_kr_pt2.dat',skiprows=1)[:, 2]
pim_xe_Q2 = np.loadtxt('../plot_data/HERMES/pim_xe_pt2.dat',skiprows=1)[:, 2]

pi0_ne_Q2 = np.loadtxt('../plot_data/HERMES/pi0_ne_pt2.dat',skiprows=1)[:, 2]
pi0_kr_Q2 = np.loadtxt('../plot_data/HERMES/pi0_kr_pt2.dat',skiprows=1)[:, 2]
pi0_xe_Q2 = np.loadtxt('../plot_data/HERMES/pi0_xe_pt2.dat',skiprows=1)[:, 2]

pip_ne_Chi2 = np.loadtxt('../plot_data/HERMES/pip_ne_pt2.dat',skiprows=1)[:, 10]
pip_kr_Chi2 = np.loadtxt('../plot_data/HERMES/pip_kr_pt2.dat',skiprows=1)[:, 10]
pip_xe_Chi2 = np.loadtxt('../plot_data/HERMES/pip_xe_pt2.dat',skiprows=1)[:, 10]

pim_ne_Chi2 = np.loadtxt('../plot_data/HERMES/pim_ne_pt2.dat',skiprows=1)[:, 10]
pim_kr_Chi2 = np.loadtxt('../plot_data/HERMES/pim_kr_pt2.dat',skiprows=1)[:, 10]
pim_xe_Chi2 = np.loadtxt('../plot_data/HERMES/pim_xe_pt2.dat',skiprows=1)[:, 10]

pi0_ne_Chi2 = np.loadtxt('../plot_data/HERMES/pi0_ne_pt2.dat',skiprows=1)[:, 10]
pi0_kr_Chi2 = np.loadtxt('../plot_data/HERMES/pi0_kr_pt2.dat',skiprows=1)[:, 10]
pi0_xe_Chi2 = np.loadtxt('../plot_data/HERMES/pi0_xe_pt2.dat',skiprows=1)[:, 10]

pip_ne_z = np.loadtxt('../plot_data/HERMES/pip_ne_pt2.dat',skiprows=1)[:, 1]
pip_kr_z = np.loadtxt('../plot_data/HERMES/pip_kr_pt2.dat',skiprows=1)[:, 1]
pip_xe_z = np.loadtxt('../plot_data/HERMES/pip_xe_pt2.dat',skiprows=1)[:, 1]

pim_ne_z = np.loadtxt('../plot_data/HERMES/pim_ne_pt2.dat',skiprows=1)[:, 1]
pim_kr_z = np.loadtxt('../plot_data/HERMES/pim_kr_pt2.dat',skiprows=1)[:, 1]
pim_xe_z = np.loadtxt('../plot_data/HERMES/pim_xe_pt2.dat',skiprows=1)[:, 1]

pi0_ne_z = np.loadtxt('../plot_data/HERMES/pi0_ne_pt2.dat',skiprows=1)[:, 1]
pi0_kr_z = np.loadtxt('../plot_data/HERMES/pi0_kr_pt2.dat',skiprows=1)[:, 1]
pi0_xe_z = np.loadtxt('../plot_data/HERMES/pi0_xe_pt2.dat',skiprows=1)[:, 1]

# %%
fig, axs = plt.subplots(3, 3, sharex='col', sharey='row',
                        gridspec_kw={'hspace': 0, 'wspace': 0})

#### All share the same axis (plot)
######## Set Size of Font
SizeOfFont = 10

### Set Figure Size
fig.set_size_inches(5,5)

axs[0,0].scatter(pip_ne_Q2,pip_ne_Chi2, color = 'black',label = '${\mathrm{Ne}}$')
axs[1,0].scatter(pip_kr_Q2,pip_kr_Chi2, color = 'green',label = '${\mathrm{Kr}}$')
axs[2,0].scatter(pip_xe_Q2,pip_xe_Chi2, color = 'blue',label = '${\mathrm{Xe}}$')

axs[0,1].scatter(pi0_ne_Q2,pi0_ne_Chi2, color = 'black',label = '${\mathrm{Ne}}$')
axs[1,1].scatter(pi0_kr_Q2,pi0_kr_Chi2, color = 'green',label = '${\mathrm{Kr}}$')
axs[2,1].scatter(pi0_xe_Q2,pi0_xe_Chi2, color = 'blue',label = '${\mathrm{Xe}}$')

axs[0,2].scatter(pim_ne_Q2,pim_ne_Chi2, color = 'black',label = '${\mathrm{Ne}}$')
axs[1,2].scatter(pim_kr_Q2,pim_kr_Chi2, color = 'green',label = '${\mathrm{Kr}}$')
axs[2,2].scatter(pim_xe_Q2,pim_xe_Chi2, color = 'blue',label = '${\mathrm{Xe}}$')

props = dict(boxstyle='round', facecolor='white', alpha=0)



axs[1,0].set_ylabel(r"\rm $\mathrm{CHI2}$", fontsize = SizeOfFont,rotation = 0,labelpad = 30)
axs[2,1].set_xlabel(r"\rm $\mathrm{Q^2}$ $\mathrm{(GeV^2)}$", fontsize = SizeOfFont, labelpad = 10)



#axs[0].set_ylim(0.6,1.05)


axs[0,0].text(0.5, 1.1,  r"\rm $\pi^+$", transform=axs[0,0].transAxes, fontsize=SizeOfFont,
    verticalalignment='top', bbox=props)

axs[0,1].text(0.5, 1.1,  r"\rm $\pi^0$", transform=axs[0,1].transAxes, fontsize=SizeOfFont,
    verticalalignment='top', bbox=props)

axs[0,2].text(0.5, 1.1,  r"\rm $\pi^-$", transform=axs[0,2].transAxes, fontsize=SizeOfFont,
    verticalalignment='top', bbox=props)

for i in range(3):
    for j in range(3):
        axs[i,j].legend(frameon = False,fontsize = SizeOfFont,loc='upper center', bbox_to_anchor=(1.15, 0.9))


#for i in range(3):
        #axs[i].tick_params(axis = 'both', direction ='in',labelsize = SizeOfFont)
        
        
fig.savefig('SIDIS_newFF.pdf', bbox_inches = "tight")

# %%
fig, axs = plt.subplots(3, 3, sharex='col', sharey='row',
                        gridspec_kw={'hspace': 0, 'wspace': 0})

#### All share the same axis (plot)
######## Set Size of Font
SizeOfFont = 10

### Set Figure Size
fig.set_size_inches(5,5)

axs[0,0].scatter(pip_ne_z,pip_ne_Chi2, color = 'black',label = '${\mathrm{Ne}}$')
axs[1,0].scatter(pip_kr_z,pip_kr_Chi2, color = 'green',label = '${\mathrm{Kr}}$')
axs[2,0].scatter(pip_xe_z,pip_xe_Chi2, color = 'blue',label = '${\mathrm{Xe}}$')

axs[0,1].scatter(pi0_ne_z,pi0_ne_Chi2, color = 'black',label = '${\mathrm{Ne}}$')
axs[1,1].scatter(pi0_kr_z,pi0_kr_Chi2, color = 'green',label = '${\mathrm{Kr}}$')
axs[2,1].scatter(pi0_xe_z,pi0_xe_Chi2, color = 'blue',label = '${\mathrm{Xe}}$')

axs[0,2].scatter(pim_ne_z,pim_ne_Chi2, color = 'black',label = '${\mathrm{Ne}}$')
axs[1,2].scatter(pim_kr_z,pim_kr_Chi2, color = 'green',label = '${\mathrm{Kr}}$')
axs[2,2].scatter(pim_xe_z,pim_xe_Chi2, color = 'blue',label = '${\mathrm{Xe}}$')

props = dict(boxstyle='round', facecolor='white', alpha=0)



axs[1,0].set_ylabel(r"\rm $\mathrm{CHI2}$", fontsize = SizeOfFont,rotation = 0,labelpad = 30)
axs[2,1].set_xlabel(r"\rm $z$", fontsize = SizeOfFont, labelpad = 10)



#axs[0].set_ylim(0.6,1.05)


axs[0,0].text(0.5, 1.1,  r"\rm $\pi^+$", transform=axs[0,0].transAxes, fontsize=SizeOfFont,
    verticalalignment='top', bbox=props)

axs[0,1].text(0.5, 1.1,  r"\rm $\pi^0$", transform=axs[0,1].transAxes, fontsize=SizeOfFont,
    verticalalignment='top', bbox=props)

axs[0,2].text(0.5, 1.1,  r"\rm $\pi^-$", transform=axs[0,2].transAxes, fontsize=SizeOfFont,
    verticalalignment='top', bbox=props)

for i in range(3):
    for j in range(3):
        axs[i,j].legend(frameon = False,fontsize = SizeOfFont,loc='upper center', bbox_to_anchor=(1.15, 0.9))


#for i in range(3):
        #axs[i].tick_params(axis = 'both', direction ='in',labelsize = SizeOfFont)
        
        
fig.savefig('SIDIS_newFF.pdf', bbox_inches = "tight")

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.concatenate((pip_ne_Q2,pip_kr_Q2,pip_xe_Q2,Q21,Q22,Q23))
y = np.array([20,20,20,84,84,84,131,131,131,12,12,12,12,12,12,12,12,12,12,12,12,12,12,12,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,208,208,208,208,208,208,208,208,208,208,208,208,208,208,208,208])
z = np.concatenate((pip_ne_Chi2,pip_kr_Chi2,pip_xe_Chi2,Chi21,Chi22,Chi23))

# Here we are creating the 2D histogram
plt.hist2d(x, z, bins=(50, 50), cmap=plt.cm.jet)
plt.colorbar()

# Setting the labels
plt.xlabel("$\mathrm{Q}^2 (\mathrm{GeV}^2)$")
plt.ylabel("$\chi^2$")

# Setting the title
plt.title("2D Histogram")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[79], line 4
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 4 x = np.concatenate((pip_ne_Q2,pip_kr_Q2,pip_xe_Q2,Q21,Q22,Q23))
#       5 y = np.array([20,20,20,84,84,84,131,131,131,12,12,12,12,12,12,12,12,12,12,12,12,12,12,12,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,208,208,208,208,208,208,208,208,208,208,208,208,208,208,208,208])
#       6 z = np.concatenate((pip_ne_Chi2,pip_kr_Chi2,pip_xe_Chi2,Chi21,Chi22,Chi23))
#
# NameError: name 'Q21' is not defined

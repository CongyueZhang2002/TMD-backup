# %%
import os
import pandas as pd
import numpy as np
import pylab as py
import warnings
import matplotlib.pyplot as plt
from  matplotlib import rc
from matplotlib.colors import LogNorm
from matplotlib import font_manager
import matplotlib
rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
rc('text',usetex=True)
from scipy.interpolate import interp1d
from scipy.interpolate import make_interp_spline as spline
matplotlib.rcParams['text.latex.preamble']=[r"\usepackage{amsmath}"]
from matplotlib.ticker import ScalarFormatter,MaxNLocator,LogLocator,NullFormatter,FuncFormatter
warnings.filterwarnings('ignore')
import matplotlib.font_manager
from matplotlib.ticker import MultipleLocator, FormatStrFormatter,AutoMinorLocator
from matplotlib.pyplot import gca

# %%
pwd = os.getcwd()
#pwd = pwd + '/Nuclear-TMDs/plots'
path2dat = pwd + '/contour/example'
datalst = os.listdir(path2dat)

# %%
newdatalst = []
for address in datalst:
    if("PDF_" in address):
        print(address)
        newdatalst.append(address)
# Out:
# PDF_Au_Q0.csv
# PDF_p_Q0.csv
# PDF_NLO.o
# PDF_NLO.f
# PDF_Au_MZ.csv
# PDF_Au_10.csv
# PDF_p_10.csv

# %%
p_df = pd.read_csv(path2dat + '/PDF_p_Q0.csv', delimiter = ',',delim_whitespace=True)
p_10_df = pd.read_csv(path2dat + '/PDF_p_10.csv', delimiter = ',',delim_whitespace=True)
Au_Q0_df = pd.read_csv(path2dat + '/PDF_Au_Q0.csv', delimiter = ',',delim_whitespace=True)
Au_10_df = pd.read_csv(path2dat + '/PDF_Au_10.csv', delimiter = ',',delim_whitespace=True)

# %%
p_df[1769:1770]["up"] = np.float(p_df[1768:1769]["up"])
p_10_df[1769:1770]["up"] = np.float(p_10_df[1768:1769]["up"])
Au_Q0_df[1769:1770]["u"] = np.float(Au_Q0_df[1768:1769]["u"])
Au_10_df[1769:1770]["u"] = np.float(Au_10_df[1768:1769]["u"])

# %%
Au_Q0_df = Au_Q0_df.drop('d',axis =1)

# %%
for i in range(len(p_df)):
    p_df["up"][i] = np.abs(p_df["up"][i])
    p_10_df["up"][i] = np.abs(p_10_df["up"][i])
    Au_Q0_df["u"][i] = np.abs(Au_Q0_df["u"][i])
    Au_10_df["u"][i] = np.abs(Au_10_df["u"][i])

# %%
for i in range(len(p_df)):
    if((np.abs(p_df['kx'][i]) > 0.9) or (np.abs(p_df['ky'][i]) > 0.9) ):
        p_df['up'][i] = 0.001
        #Au_Q0_df['u'][i] = 0.01

# %%
p_df.to_csv('TMD_Data/p_lo.csv', header = False, index = False)
p_10_df.to_csv('TMD_Data/p_hi.csv', header = False, index = False)
Au_Q0_df.to_csv('TMD_Data/Au_lo.csv', header = False, index = False)
Au_10_df.to_csv('TMD_Data/Au_hi.csv', header = False, index = False)

# %%
ax = plt.axes(projection='3d')
ax.plot3D(p_df['kx'], p_df['ky'], p_df['up'], 'orange')
ax.plot3D(Au_Q0_df['kx'], Au_Q0_df['ky'], Au_Q0_df['u'], 'blue')
#ax.plot3D(Au_Q0_df['kx'], Au_Q0_df['ky'], np.log(Au_Q0_df['u']), 'blue')

# %%
ax = plt.axes(projection='3d')
ax.plot3D(p_10_df['kx'], p_10_df['ky'], np.abs(p_10_df['up']), 'orange')
ax.plot3D(Au_10_df['kx'], Au_10_df['ky'], np.abs(Au_10_df['u']), 'blue')

# %%
p_df[1755:1770]
# Out:
#        kx   ky        up
# 1755  0.0 -1.4 -0.043316
# 1756  0.0 -1.3 -0.001125
# 1757  0.0 -1.2  0.075512
# 1758  0.0 -1.1  0.203792
# 1759  0.0 -1.0  0.404157
# 1760  0.0 -0.9  0.697740
# 1761  0.0 -0.8  1.101789
# 1762  0.0 -0.7  1.623608
# 1763  0.0 -0.6  2.254109
# 1764  0.0 -0.5  2.962983
# 1765  0.0 -0.4  3.697745
# 1766  0.0 -0.3  4.388150
# 1767  0.0 -0.2  4.956356
# 1768  0.0 -0.1  5.331042
# 1769  0.0  0.0  5.331042

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc
rc('text', usetex = True)

# %%
#Get Data
#pip 
pip_he_nu_df = pd.read_csv('plot_data/pip_he_nu.dat', sep ='\s+')
pip_ne_nu_df = pd.read_csv('plot_data/pip_ne_nu.dat', sep ='\s+')
pip_kr_nu_df = pd.read_csv('plot_data/pip_kr_nu.dat', sep ='\s+')
pip_xe_nu_df = pd.read_csv('plot_data/pip_xe_nu.dat', sep ='\s+')

pip_he_z_df = pd.read_csv('plot_data/pip_he_z.dat', sep ='\s+')
pip_ne_z_df = pd.read_csv('plot_data/pip_ne_z.dat', sep ='\s+')
pip_kr_z_df = pd.read_csv('plot_data/pip_kr_z.dat', sep ='\s+')
pip_xe_z_df = pd.read_csv('plot_data/pip_xe_z.dat', sep ='\s+')

pip_he_q2_df = pd.read_csv('plot_data/pip_he_q2.dat', sep ='\s+')
pip_ne_q2_df = pd.read_csv('plot_data/pip_ne_q2.dat', sep ='\s+')
pip_kr_q2_df = pd.read_csv('plot_data/pip_kr_q2.dat', sep ='\s+')
pip_xe_q2_df = pd.read_csv('plot_data/pip_xe_q2.dat', sep ='\s+')

pip_he_pt2_df = pd.read_csv('plot_data/pip_he_pt2.dat', sep ='\s+')
pip_ne_pt2_df = pd.read_csv('plot_data/pip_ne_pt2.dat', sep ='\s+')
pip_kr_pt2_df = pd.read_csv('plot_data/pip_kr_pt2.dat', sep ='\s+')
pip_xe_pt2_df = pd.read_csv('plot_data/pip_xe_pt2.dat', sep ='\s+')

#kp 
kp_he_nu_df = pd.read_csv('plot_data/kp_he_nu.dat', sep ='\s+')
kp_ne_nu_df = pd.read_csv('plot_data/kp_ne_nu.dat', sep ='\s+')
kp_kr_nu_df = pd.read_csv('plot_data/kp_kr_nu.dat', sep ='\s+')
kp_xe_nu_df = pd.read_csv('plot_data/kp_xe_nu.dat', sep ='\s+')

kp_he_z_df = pd.read_csv('plot_data/kp_he_z.dat', sep ='\s+')
kp_ne_z_df = pd.read_csv('plot_data/kp_ne_z.dat', sep ='\s+')
kp_kr_z_df = pd.read_csv('plot_data/kp_kr_z.dat', sep ='\s+')
kp_xe_z_df = pd.read_csv('plot_data/kp_xe_z.dat', sep ='\s+')

kp_he_q2_df = pd.read_csv('plot_data/kp_he_q2.dat', sep ='\s+')
kp_ne_q2_df = pd.read_csv('plot_data/kp_ne_q2.dat', sep ='\s+')
kp_kr_q2_df = pd.read_csv('plot_data/kp_kr_q2.dat', sep ='\s+')
kp_xe_q2_df = pd.read_csv('plot_data/kp_xe_q2.dat', sep ='\s+')

kp_he_pt2_df = pd.read_csv('plot_data/kp_he_pt2.dat', sep ='\s+')
kp_ne_pt2_df = pd.read_csv('plot_data/kp_ne_pt2.dat', sep ='\s+')
kp_kr_pt2_df = pd.read_csv('plot_data/kp_kr_pt2.dat', sep ='\s+')
kp_xe_pt2_df = pd.read_csv('plot_data/kp_xe_pt2.dat', sep ='\s+')

#pim
pim_he_nu_df = pd.read_csv('plot_data/pim_he_nu.dat', sep ='\s+')
pim_ne_nu_df = pd.read_csv('plot_data/pim_ne_nu.dat', sep ='\s+')
pim_kr_nu_df = pd.read_csv('plot_data/pim_kr_nu.dat', sep ='\s+')
pim_xe_nu_df = pd.read_csv('plot_data/pim_xe_nu.dat', sep ='\s+')

pim_he_z_df = pd.read_csv('plot_data/pim_he_z.dat', sep ='\s+')
pim_ne_z_df = pd.read_csv('plot_data/pim_ne_z.dat', sep ='\s+')
pim_kr_z_df = pd.read_csv('plot_data/pim_kr_z.dat', sep ='\s+')
pim_xe_z_df = pd.read_csv('plot_data/pim_xe_z.dat', sep ='\s+')

pim_he_q2_df = pd.read_csv('plot_data/pim_he_q2.dat', sep ='\s+')
pim_ne_q2_df = pd.read_csv('plot_data/pim_ne_q2.dat', sep ='\s+')
pim_kr_q2_df = pd.read_csv('plot_data/pim_kr_q2.dat', sep ='\s+')
pim_xe_q2_df = pd.read_csv('plot_data/pim_xe_q2.dat', sep ='\s+')

pim_he_pt2_df = pd.read_csv('plot_data/pim_he_pt2.dat', sep ='\s+')
pim_ne_pt2_df = pd.read_csv('plot_data/pim_ne_pt2.dat', sep ='\s+')
pim_kr_pt2_df = pd.read_csv('plot_data/pim_kr_pt2.dat', sep ='\s+')
pim_xe_pt2_df = pd.read_csv('plot_data/pim_xe_pt2.dat', sep ='\s+')

#km
km_he_nu_df = pd.read_csv('plot_data/km_he_nu.dat', sep ='\s+')
km_ne_nu_df = pd.read_csv('plot_data/km_ne_nu.dat', sep ='\s+')
km_kr_nu_df = pd.read_csv('plot_data/km_kr_nu.dat', sep ='\s+')
km_xe_nu_df = pd.read_csv('plot_data/km_xe_nu.dat', sep ='\s+')

km_he_z_df = pd.read_csv('plot_data/km_he_z.dat', sep ='\s+')
km_ne_z_df = pd.read_csv('plot_data/km_ne_z.dat', sep ='\s+')
km_kr_z_df = pd.read_csv('plot_data/km_kr_z.dat', sep ='\s+')
km_xe_z_df = pd.read_csv('plot_data/km_xe_z.dat', sep ='\s+')

km_he_q2_df = pd.read_csv('plot_data/km_he_q2.dat', sep ='\s+')
km_ne_q2_df = pd.read_csv('plot_data/km_ne_q2.dat', sep ='\s+')
km_kr_q2_df = pd.read_csv('plot_data/km_kr_q2.dat', sep ='\s+')
km_xe_q2_df = pd.read_csv('plot_data/km_xe_q2.dat', sep ='\s+')

km_he_pt2_df = pd.read_csv('plot_data/km_he_pt2.dat', sep ='\s+')
km_ne_pt2_df = pd.read_csv('plot_data/km_ne_pt2.dat', sep ='\s+')
km_kr_pt2_df = pd.read_csv('plot_data/km_kr_pt2.dat', sep ='\s+')
km_xe_pt2_df = pd.read_csv('plot_data/km_xe_pt2.dat', sep ='\s+')

#pip_ne_nu_df.head(10)

# %%
pip_he_nu_df[(pip_he_nu_df.pt2<0.7) & (pip_he_nu_df.Z<0.7)& (np.sqrt(pip_he_nu_df.pt2)/(np.sqrt(pip_he_nu_df.Q2)*pip_he_nu_df.Z)<0.75)]
# Out:
#       Nu     Z    Q2    pt2  MULT-RATIO   STAT    SYS       fuu      fuua  \
# 0   5.27  0.59  1.84  0.228       0.968  0.021  0.029  0.000034  0.000035
# 1   7.14  0.51  2.02  0.153       0.970  0.012  0.031  0.000067  0.000069
# 2   9.08  0.47  2.18  0.137       0.951  0.009  0.030  0.000086  0.000088
# 3  11.02  0.44  2.38  0.141       0.958  0.008  0.031  0.000089  0.000090
# 4  13.00  0.42  2.54  0.166       0.962  0.008  0.031  0.000082  0.000083
# 5  14.98  0.40  2.61  0.194       0.969  0.008  0.030  0.000081  0.000082
#
#         DIS
# 0  1.017282
# 1  1.019834
# 2  1.020149
# 3  1.019743
# 4  1.019026
# 5  1.017862

# %%
class multdata:
    
    def __init__(self, file, var):
        file = file[(file.pt2<0.7) & (file.Z<0.7)& (np.sqrt(file.pt2)/(np.sqrt(file.Q2)*file.Z)<0.75)]
        self.xdata  = file[var]
        self.var    = var
        self.nu     = file['Nu']
        self.z      = file['Z']
        self.Q2     = file['Q2']
        self.pt2    = file['pt2']
        self.mult   = file['MULT-RATIO']
        self.stat   = file['STAT']
        self.sys    = file['SYS']
        self.Ra     = file['fuua']/file['fuu']/file['DIS']
        self.error  = np.sqrt((file['STAT'])**2+ (file['SYS'])**2)

# %%
class multplot:
    
    def __init__(self, data, nucleus, plotcolor):
        self.data = data
        self.nucleus = nucleus
        self.plotcolor = plotcolor
        
    def newplot(self,label):
        plt.title(label, fontsize = 'x-large')
        plt.axhline(1,color ='black',linewidth = 0.5)
        plt.ylabel(r"\rm $R^h_A$", fontsize = 'x-large',rotation = 0,labelpad = 15)
        plt.xlabel(self.data.var,fontsize = 'x-large', labelpad = 10)
        
    def plot(self):
        plt.errorbar(self.data.xdata, self.data.mult, self.data.error, fmt = "o",color = self.plotcolor, ecolor = self.plotcolor, uplims=False, lolims=False, capsize = 5, capthick =0.8, barsabove = False,label = self.nucleus)
        plt.plot(self.data.xdata, self.data.Ra, color = self.plotcolor)
        plt.legend(loc = 'best')
        
    def endplot(self,ylow,yhigh):
        plt.ylim(ylow,yhigh)
        fig = plt.gcf()
        ax = plt.gca()
        ax.tick_params(axis = 'both', direction ='in',labelsize = 'x-large')
        plt.show()
        return fig, ax    
        
    def newaxesplot(self,axes,ylow,yhigh):
        axes.axhline(1,color = 'black', linewidth = 1)
        axes.tick_params(axis = 'both', direction ='in',labelsize = 'x-large')
        axes.set_ylim(ylow,yhigh)
    
    def axesplot(self,axes):
        axes.errorbar(self.data.xdata, self.data.mult, self.data.error, fmt = "o",color = self.plotcolor, ecolor = self.plotcolor, uplims=False, lolims=False, capsize = 5, capthick =0.8, barsabove = False,label = self.nucleus)
        axes.plot(self.data.xdata, self.data.Ra, color = self.plotcolor)

# %%
# Setup Arrays
#pip
pip_he_nu = multdata(pip_he_nu_df,'Nu')
pip_ne_nu = multdata(pip_ne_nu_df,'Nu')
pip_kr_nu = multdata(pip_kr_nu_df,'Nu')
pip_xe_nu = multdata(pip_xe_nu_df,'Nu')

pip_he_z = multdata(pip_he_z_df,'Z')
pip_ne_z = multdata(pip_ne_z_df,'Z')
pip_kr_z = multdata(pip_kr_z_df,'Z')
pip_xe_z = multdata(pip_xe_z_df,'Z')

pip_he_q2 = multdata(pip_he_q2_df,'Q2')
pip_ne_q2 = multdata(pip_ne_q2_df,'Q2')
pip_kr_q2 = multdata(pip_kr_q2_df,'Q2')
pip_xe_q2 = multdata(pip_xe_q2_df,'Q2')

pip_he_pt2 = multdata(pip_he_pt2_df,'pt2')
pip_ne_pt2 = multdata(pip_ne_pt2_df,'pt2')
pip_kr_pt2 = multdata(pip_kr_pt2_df,'pt2')
pip_xe_pt2 = multdata(pip_xe_pt2_df,'pt2')

#kp
kp_he_nu = multdata(kp_he_nu_df,'Nu')
kp_ne_nu = multdata(kp_ne_nu_df,'Nu')
kp_kr_nu = multdata(kp_kr_nu_df,'Nu')
kp_xe_nu = multdata(kp_xe_nu_df,'Nu')

kp_he_z = multdata(kp_he_z_df,'Z')
kp_ne_z = multdata(kp_ne_z_df,'Z')
kp_kr_z = multdata(kp_kr_z_df,'Z')
kp_xe_z = multdata(kp_xe_z_df,'Z')

kp_he_q2 = multdata(kp_he_q2_df,'Q2')
kp_ne_q2 = multdata(kp_ne_q2_df,'Q2')
kp_kr_q2 = multdata(kp_kr_q2_df,'Q2')
kp_xe_q2 = multdata(kp_xe_q2_df,'Q2')

kp_he_pt2 = multdata(kp_he_pt2_df,'pt2')
kp_ne_pt2 = multdata(kp_ne_pt2_df,'pt2')
kp_kr_pt2 = multdata(kp_kr_pt2_df,'pt2')
kp_xe_pt2 = multdata(kp_xe_pt2_df,'pt2')

#pim
pim_he_nu = multdata(pim_he_nu_df,'Nu')
pim_ne_nu = multdata(pim_ne_nu_df,'Nu')
pim_kr_nu = multdata(pim_kr_nu_df,'Nu')
pim_xe_nu = multdata(pim_xe_nu_df,'Nu')

pim_he_z = multdata(pim_he_z_df,'Z')
pim_ne_z = multdata(pim_ne_z_df,'Z')
pim_kr_z = multdata(pim_kr_z_df,'Z')
pim_xe_z = multdata(pim_xe_z_df,'Z')

pim_he_q2 = multdata(pim_he_q2_df,'Q2')
pim_ne_q2 = multdata(pim_ne_q2_df,'Q2')
pim_kr_q2 = multdata(pim_kr_q2_df,'Q2')
pim_xe_q2 = multdata(pim_xe_q2_df,'Q2')

pim_he_pt2 = multdata(pim_he_pt2_df,'pt2')
pim_ne_pt2 = multdata(pim_ne_pt2_df,'pt2')
pim_kr_pt2 = multdata(pim_kr_pt2_df,'pt2')
pim_xe_pt2 = multdata(pim_xe_pt2_df,'pt2')

#km
km_he_nu = multdata(km_he_nu_df,'Nu')
km_ne_nu = multdata(km_ne_nu_df,'Nu')
km_kr_nu = multdata(km_kr_nu_df,'Nu')
km_xe_nu = multdata(km_xe_nu_df,'Nu')

km_he_z = multdata(km_he_z_df,'Z')
km_ne_z = multdata(km_ne_z_df,'Z')
km_kr_z = multdata(km_kr_z_df,'Z')
km_xe_z = multdata(km_xe_z_df,'Z')

km_he_q2 = multdata(km_he_q2_df,'Q2')
km_ne_q2 = multdata(km_ne_q2_df,'Q2')
km_kr_q2 = multdata(km_kr_q2_df,'Q2')
km_xe_q2 = multdata(km_xe_q2_df,'Q2')

km_he_pt2 = multdata(km_he_pt2_df,'pt2')
km_ne_pt2 = multdata(km_ne_pt2_df,'pt2')
km_kr_pt2 = multdata(km_kr_pt2_df,'pt2')
km_xe_pt2 = multdata(km_xe_pt2_df,'pt2')

# %%
# Setup Plot Data
#pip
multplot_pip_he_nu = multplot(pip_he_nu, 'He', 'red')
multplot_pip_ne_nu = multplot(pip_ne_nu, 'Ne', 'black')
multplot_pip_kr_nu = multplot(pip_kr_nu, 'Kr', 'green')
multplot_pip_xe_nu = multplot(pip_xe_nu, 'Xe', 'blue')


multplot_pip_he_z = multplot(pip_he_z, 'He', 'red')
multplot_pip_ne_z = multplot(pip_ne_z, 'Ne', 'black')
multplot_pip_kr_z = multplot(pip_kr_z, 'Kr', 'green')
multplot_pip_xe_z = multplot(pip_xe_z, 'Xe', 'blue')

multplot_pip_he_q2 = multplot(pip_he_q2, 'He', 'red')
multplot_pip_ne_q2 = multplot(pip_ne_q2, 'Ne', 'black')
multplot_pip_kr_q2 = multplot(pip_kr_q2, 'Kr', 'green')
multplot_pip_xe_q2 = multplot(pip_xe_q2, 'Xe', 'blue')

multplot_pip_he_pt2 = multplot(pip_he_pt2, 'He', 'red')
multplot_pip_ne_pt2 = multplot(pip_ne_pt2, 'Ne', 'black')
multplot_pip_kr_pt2 = multplot(pip_kr_pt2, 'Kr', 'green')
multplot_pip_xe_pt2 = multplot(pip_xe_pt2, 'Xe', 'blue')

#kp
multplot_kp_he_nu = multplot(kp_he_nu, 'He', 'red')
multplot_kp_ne_nu = multplot(kp_ne_nu, 'Ne', 'black')
multplot_kp_kr_nu = multplot(kp_kr_nu, 'Kr', 'green')
multplot_kp_xe_nu = multplot(kp_xe_nu, 'Xe', 'blue')


multplot_kp_he_z = multplot(kp_he_z, 'He', 'red')
multplot_kp_ne_z = multplot(kp_ne_z, 'Ne', 'black')
multplot_kp_kr_z = multplot(kp_kr_z, 'Kr', 'green')
multplot_kp_xe_z = multplot(kp_xe_z, 'Xe', 'blue')

multplot_kp_he_q2 = multplot(kp_he_q2, 'He', 'red')
multplot_kp_ne_q2 = multplot(kp_ne_q2, 'Ne', 'black')
multplot_kp_kr_q2 = multplot(kp_kr_q2, 'Kr', 'green')
multplot_kp_xe_q2 = multplot(kp_xe_q2, 'Xe', 'blue')

multplot_kp_he_pt2 = multplot(kp_he_pt2, 'He', 'red')
multplot_kp_ne_pt2 = multplot(kp_ne_pt2, 'Ne', 'black')
multplot_kp_kr_pt2 = multplot(kp_kr_pt2, 'Kr', 'green')
multplot_kp_xe_pt2 = multplot(kp_xe_pt2, 'Xe', 'blue')

# Setup Plot Data
#pim
multplot_pim_he_nu = multplot(pim_he_nu, 'He', 'red')
multplot_pim_ne_nu = multplot(pim_ne_nu, 'Ne', 'black')
multplot_pim_kr_nu = multplot(pim_kr_nu, 'Kr', 'green')
multplot_pim_xe_nu = multplot(pim_xe_nu, 'Xe', 'blue')


multplot_pim_he_z = multplot(pim_he_z, 'He', 'red')
multplot_pim_ne_z = multplot(pim_ne_z, 'Ne', 'black')
multplot_pim_kr_z = multplot(pim_kr_z, 'Kr', 'green')
multplot_pim_xe_z = multplot(pim_xe_z, 'Xe', 'blue')

multplot_pim_he_q2 = multplot(pim_he_q2, 'He', 'red')
multplot_pim_ne_q2 = multplot(pim_ne_q2, 'Ne', 'black')
multplot_pim_kr_q2 = multplot(pim_kr_q2, 'Kr', 'green')
multplot_pim_xe_q2 = multplot(pim_xe_q2, 'Xe', 'blue')

multplot_pim_he_pt2 = multplot(pim_he_pt2, 'He', 'red')
multplot_pim_ne_pt2 = multplot(pim_ne_pt2, 'Ne', 'black')
multplot_pim_kr_pt2 = multplot(pim_kr_pt2, 'Kr', 'green')
multplot_pim_xe_pt2 = multplot(pim_xe_pt2, 'Xe', 'blue')

#km
multplot_km_he_nu = multplot(km_he_nu, 'He', 'red')
multplot_km_ne_nu = multplot(km_ne_nu, 'Ne', 'black')
multplot_km_kr_nu = multplot(km_kr_nu, 'Kr', 'green')
multplot_km_xe_nu = multplot(km_xe_nu, 'Xe', 'blue')


multplot_km_he_z = multplot(km_he_z, 'He', 'red')
multplot_km_ne_z = multplot(km_ne_z, 'Ne', 'black')
multplot_km_kr_z = multplot(km_kr_z, 'Kr', 'green')
multplot_km_xe_z = multplot(km_xe_z, 'Xe', 'blue')

multplot_km_he_q2 = multplot(km_he_q2, 'He', 'red')
multplot_km_ne_q2 = multplot(km_ne_q2, 'Ne', 'black')
multplot_km_kr_q2 = multplot(km_kr_q2, 'Kr', 'green')
multplot_km_xe_q2 = multplot(km_xe_q2, 'Xe', 'blue')

multplot_km_he_pt2 = multplot(km_he_pt2, 'He', 'red')
multplot_km_ne_pt2 = multplot(km_ne_pt2, 'Ne', 'black')
multplot_km_kr_pt2 = multplot(km_kr_pt2, 'Kr', 'green')
multplot_km_xe_pt2 = multplot(km_xe_pt2, 'Xe', 'blue')

# %%
# Produce Plots
multplot_pip_he_nu.newplot('Multiplicity Ratio for $\pi^+$ production from A')
fig1 = plt.gcf() 
fig1.set_size_inches(11,6) 
multplot_pip_he_nu.plot()
multplot_pip_ne_nu.plot()
multplot_pip_kr_nu.plot()
multplot_pip_xe_nu.plot()
multplot_pip_he_nu.endplot(0.4,1.2)


multplot_pip_he_z.newplot('Multiplicity Ratio for $\pi^+$ production from A')
fig2 = plt.gcf() 
fig2.set_size_inches(11,6) 
multplot_pip_he_z.plot()
multplot_pip_ne_z.plot()
multplot_pip_kr_z.plot()
multplot_pip_xe_z.plot()
multplot_pip_he_z.endplot(0.4,1.2)

multplot_pip_he_q2.newplot('Multiplicity Ratio for $\pi^+$ production from A')
fig3 = plt.gcf() 
fig3.set_size_inches(11,6) 
multplot_pip_he_q2.plot()
multplot_pip_ne_q2.plot()
multplot_pip_kr_q2.plot()
multplot_pip_xe_q2.plot()
multplot_pip_he_q2.endplot(0.4,1.4)

multplot_pip_he_pt2.newplot('Multiplicity Ratio for $\pi^+$ production from A')
fig4 = plt.gcf() 
fig4.set_size_inches(11,6) 
multplot_pip_he_pt2.plot()
multplot_pip_ne_pt2.plot()
multplot_pip_kr_pt2.plot()
multplot_pip_xe_pt2.plot()
multplot_pip_he_pt2.endplot(0.4,1.2)
# Out:
# (<Figure size 792x432 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fa5c10ddac8>)

# %%
# Produce Plots
multplot_kp_he_nu.newplot('Multiplicity Ratio for $K^+$ production from A')
fig1 = plt.gcf() 
fig1.set_size_inches(11,6) 
multplot_kp_he_nu.plot()
multplot_kp_ne_nu.plot()
multplot_kp_kr_nu.plot()
multplot_kp_xe_nu.plot()
multplot_kp_he_nu.endplot(0.4,1.2)


multplot_kp_he_z.newplot('Multiplicity Ratio for $K^+$ production from A')
fig2 = plt.gcf() 
fig2.set_size_inches(11,6) 
multplot_kp_he_z.plot()
multplot_kp_ne_z.plot()
multplot_kp_kr_z.plot()
multplot_kp_xe_z.plot()
multplot_kp_he_z.endplot(0.4,1.2)

multplot_kp_he_q2.newplot('Multiplicity Ratio for $K^+$ production from A')
fig3 = plt.gcf() 
fig3.set_size_inches(11,6) 
multplot_kp_he_q2.plot()
multplot_kp_ne_q2.plot()
multplot_kp_kr_q2.plot()
multplot_kp_xe_q2.plot()
multplot_kp_he_q2.endplot(0.4,1.4)

multplot_kp_he_pt2.newplot('Multiplicity Ratio for $K^+$ production from A')
fig4 = plt.gcf() 
fig4.set_size_inches(11,6) 
multplot_kp_he_pt2.plot()
multplot_kp_ne_pt2.plot()
multplot_kp_kr_pt2.plot()
multplot_kp_xe_pt2.plot()
multplot_kp_he_pt2.endplot(0.4,1.2)
# Out:
# (<Figure size 792x432 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fa5c0da3048>)

# %%
# Produce Plots
multplot_pim_he_nu.newplot('Multiplicity Ratio for $\pi^-$ production from A')
fig1 = plt.gcf() 
fig1.set_size_inches(11,6) 
multplot_pim_he_nu.plot()
multplot_pim_ne_nu.plot()
multplot_pim_kr_nu.plot()
multplot_pim_xe_nu.plot()
multplot_pim_he_nu.endplot(0.4,1.2)


multplot_pim_he_z.newplot('Multiplicity Ratio for $\pi^-$ production from A')
fig2 = plt.gcf() 
fig2.set_size_inches(11,6) 
multplot_pim_he_z.plot()
multplot_pim_ne_z.plot()
multplot_pim_kr_z.plot()
multplot_pim_xe_z.plot()
multplot_pim_he_z.endplot(0.4,1.2)

multplot_pim_he_q2.newplot('Multiplicity Ratio for $\pi^-$ production from A')
fig3 = plt.gcf() 
fig3.set_size_inches(11,6) 
multplot_pim_he_q2.plot()
multplot_pim_ne_q2.plot()
multplot_pim_kr_q2.plot()
multplot_pim_xe_q2.plot()
multplot_pim_he_q2.endplot(0.4,1.4)

multplot_pim_he_pt2.newplot('Multiplicity Ratio for $\pi^-$ production from A')
fig4 = plt.gcf() 
fig4.set_size_inches(11,6) 
multplot_pim_he_pt2.plot()
multplot_pim_ne_pt2.plot()
multplot_pim_kr_pt2.plot()
multplot_pim_xe_pt2.plot()
multplot_pim_he_pt2.endplot(0.4,1.2)
# Out:
# (<Figure size 792x432 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fa5c0afdb00>)

# %%
# Produce Plots
multplot_km_he_nu.newplot('Multiplicity Ratio for $K^-$ production from A')
fig1 = plt.gcf() 
fig1.set_size_inches(11,6) 
multplot_km_he_nu.plot()
multplot_km_ne_nu.plot()
multplot_km_kr_nu.plot()
multplot_km_xe_nu.plot()
multplot_km_he_nu.endplot(0.4,1.2)


multplot_km_he_z.newplot('Multiplicity Ratio for $K^-$ production from A')
fig2 = plt.gcf() 
fig2.set_size_inches(11,6) 
multplot_km_he_z.plot()
multplot_km_ne_z.plot()
multplot_km_kr_z.plot()
multplot_km_xe_z.plot()
multplot_km_he_z.endplot(0.4,1.2)

multplot_km_he_q2.newplot('Multiplicity Ratio for $K^-$ production from A')
fig3 = plt.gcf() 
fig3.set_size_inches(11,6) 
multplot_km_he_q2.plot()
multplot_km_ne_q2.plot()
multplot_km_kr_q2.plot()
multplot_km_xe_q2.plot()
multplot_km_he_q2.endplot(0.4,1.4)

multplot_km_he_pt2.newplot('Multiplicity Ratio for $K^-$ production from A')
fig4 = plt.gcf() 
fig4.set_size_inches(11,6) 
multplot_km_he_pt2.plot()
multplot_km_ne_pt2.plot()
multplot_km_kr_pt2.plot()
multplot_km_xe_pt2.plot()
multplot_km_he_pt2.endplot(0.4,1.2)
# Out:
# (<Figure size 792x432 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fa5c104e588>)

# %%
fig, axs = plt.subplots(4, 4, sharex='col', sharey='row',
                        gridspec_kw={'hspace': 0, 'wspace': 0})
#pip
multplot_pip_he_nu.newaxesplot(axs[0,0],0.4,1.2)
multplot_pip_he_nu.axesplot(axs[0,0])
multplot_pip_ne_nu.axesplot(axs[0,0])
multplot_pip_kr_nu.axesplot(axs[0,0])
multplot_pip_xe_nu.axesplot(axs[0,0])


multplot_pip_he_z.newaxesplot(axs[0,1],0.4,1.2)
multplot_pip_he_z.axesplot(axs[0,1])
multplot_pip_ne_z.axesplot(axs[0,1])
multplot_pip_kr_z.axesplot(axs[0,1])
multplot_pip_xe_z.axesplot(axs[0,1])


multplot_pip_he_q2.newaxesplot(axs[0,2],0.4,1.4)
multplot_pip_he_q2.axesplot(axs[0,2])
multplot_pip_ne_q2.axesplot(axs[0,2])
multplot_pip_kr_q2.axesplot(axs[0,2])
multplot_pip_xe_q2.axesplot(axs[0,2])

multplot_pip_he_pt2.newaxesplot(axs[0,3],0.4,1.4)
multplot_pip_he_pt2.axesplot(axs[0,3])
multplot_pip_ne_pt2.axesplot(axs[0,3])
multplot_pip_kr_pt2.axesplot(axs[0,3])
multplot_pip_xe_pt2.axesplot(axs[0,3])

#kp
multplot_kp_he_nu.newaxesplot(axs[1,0],0.4,1.2)
multplot_kp_he_nu.axesplot(axs[1,0])
multplot_kp_ne_nu.axesplot(axs[1,0])
multplot_kp_kr_nu.axesplot(axs[1,0])
multplot_kp_xe_nu.axesplot(axs[1,0])


multplot_kp_he_z.newaxesplot(axs[1,1],0.4,1.2)
multplot_kp_he_z.axesplot(axs[1,1])
multplot_kp_ne_z.axesplot(axs[1,1])
multplot_kp_kr_z.axesplot(axs[1,1])
multplot_kp_xe_z.axesplot(axs[1,1])


multplot_kp_he_q2.newaxesplot(axs[1,2],0.4,1.4)
multplot_kp_he_q2.axesplot(axs[1,2])
multplot_kp_ne_q2.axesplot(axs[1,2])
multplot_kp_kr_q2.axesplot(axs[1,2])
multplot_kp_xe_q2.axesplot(axs[1,2])

multplot_kp_he_pt2.newaxesplot(axs[1,3],0.4,1.4)
multplot_kp_he_pt2.axesplot(axs[1,3])
multplot_kp_ne_pt2.axesplot(axs[1,3])
multplot_kp_kr_pt2.axesplot(axs[1,3])
multplot_kp_xe_pt2.axesplot(axs[1,3])

#pim
multplot_pim_he_nu.newaxesplot(axs[2,0],0.4,1.2)
multplot_pim_he_nu.axesplot(axs[2,0])
multplot_pim_ne_nu.axesplot(axs[2,0])
multplot_pim_kr_nu.axesplot(axs[2,0])
multplot_pim_xe_nu.axesplot(axs[2,0])


multplot_pim_he_z.newaxesplot(axs[2,1],0.4,1.2)
multplot_pim_he_z.axesplot(axs[2,1])
multplot_pim_ne_z.axesplot(axs[2,1])
multplot_pim_kr_z.axesplot(axs[2,1])
multplot_pim_xe_z.axesplot(axs[2,1])


multplot_pim_he_q2.newaxesplot(axs[2,2],0.4,1.4)
multplot_pim_he_q2.axesplot(axs[2,2])
multplot_pim_ne_q2.axesplot(axs[2,2])
multplot_pim_kr_q2.axesplot(axs[2,2])
multplot_pim_xe_q2.axesplot(axs[2,2])

multplot_pim_he_pt2.newaxesplot(axs[2,3],0.4,1.4)
multplot_pim_he_pt2.axesplot(axs[2,3])
multplot_pim_ne_pt2.axesplot(axs[2,3])
multplot_pim_kr_pt2.axesplot(axs[2,3])
multplot_pim_xe_pt2.axesplot(axs[2,3])

#km
multplot_km_he_nu.newaxesplot(axs[3,0],0.4,1.2)
multplot_km_he_nu.axesplot(axs[3,0])
multplot_km_ne_nu.axesplot(axs[3,0])
multplot_km_kr_nu.axesplot(axs[3,0])
multplot_km_xe_nu.axesplot(axs[3,0])


multplot_km_he_z.newaxesplot(axs[3,1],0.4,1.2)
multplot_km_he_z.axesplot(axs[3,1])
multplot_km_ne_z.axesplot(axs[3,1])
multplot_km_kr_z.axesplot(axs[3,1])
multplot_km_xe_z.axesplot(axs[3,1])


multplot_km_he_q2.newaxesplot(axs[3,2],0.4,1.4)
multplot_km_he_q2.axesplot(axs[3,2])
multplot_km_ne_q2.axesplot(axs[3,2])
multplot_km_kr_q2.axesplot(axs[3,2])
multplot_km_xe_q2.axesplot(axs[3,2])

multplot_km_he_pt2.newaxesplot(axs[3,3],0.4,1.4)
multplot_km_he_pt2.axesplot(axs[3,3])
multplot_km_ne_pt2.axesplot(axs[3,3])
multplot_km_kr_pt2.axesplot(axs[3,3])
multplot_km_xe_pt2.axesplot(axs[3,3])

fig.suptitle(r'\rm Multiplicity Ratio $(A/D)$ for charged hadrons',fontsize = 30)
axs[0,0].set_ylabel(r"\rm $R^h_A$", fontsize = 30,rotation = 0,labelpad = 15)
axs[3,0].set_xlabel(r"\rm $\nu$ (GeV)", fontsize = 30, labelpad = 10)
axs[3,1].set_xlabel(r"\rm $z$", fontsize = 30, labelpad = 10)
axs[3,2].set_xlabel(r"\rm $Q^2$ (Ge$V^2$)", fontsize = 30, labelpad = 10)
axs[3,3].set_xlabel(r"\rm $p_t^2$ (Ge$V^2$)", fontsize = 30, labelpad = 10)

fig.set_size_inches(18,18)
axs[3,3].legend(loc = 1)

# Text Boxes ##
props = dict(boxstyle='round', facecolor='white', alpha=0)

axs[0,0].text(0.7, 0.9,  r"\rm $\pi^+$", transform=axs[0,0].transAxes, fontsize=30,
    verticalalignment='top', bbox=props)

axs[1,0].text(0.7, 0.9,  r"\rm $K^+$", transform=axs[1,0].transAxes, fontsize=30,
    verticalalignment='top', bbox=props)

axs[2,0].text(0.7, 0.9,  r"\rm $\pi^-$", transform=axs[2,0].transAxes, fontsize=30,
    verticalalignment='top', bbox=props)

axs[3,0].text(0.7, 0.9,  r"\rm $K^-$", transform=axs[3,0].transAxes, fontsize=30,
    verticalalignment='top', bbox=props)
plt.show()

# %%
fig.savefig('theory2.png')

# %%
# total, # remaining, # cut
